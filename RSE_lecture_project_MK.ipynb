# %%
# !pip install pint
# !pip install -i https://test.pypi.org/simple/ volume
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.5/307.5 kB 5.1 MB/s eta 0:00:00
# ...
# Looking in indexes: https://test.pypi.org/simple/
# ...

# %%
import pint
import volume
si= volume._si
print(volume.volume( 2 * si.m, 50 * si.cm, 2000 * si.mm,))
# Out:
# 2.0 meter ** 3
